# %%
import os
import dcex.async_support as dcex
from dotenv import load_dotenv

load_dotenv()

BITMART_API_KEY = os.getenv("BITMART_API_KEY")
BITMART_API_SECRET = os.getenv("BITMART_API_SECRET")
MEMO = os.getenv("BITMART_MEMO")

# %%
client = await dcex.bitmart(
    api_key=BITMART_API_KEY,
    api_secret=BITMART_API_SECRET,
    memo=MEMO,
)

# %% [markdown]
# # Trade

# %%
await client.place_spot_market_buy_order(product_symbol="APT-USDT-SPOT", notional="5")
# Out:
# {'message': 'OK',
#  'code': 1000,
#  'trace': '94b8c69f-aea4-43e7-8783-37814e029dfa',
#  'data': {'order_id': '1326625441708227840'}}

# %%
await client.place_spot_market_sell_order(product_symbol="APT-USDT-SPOT", size="2.2")
# Out:
# {'message': 'OK',
#  'code': 1000,
#  'trace': 'cbae1017-3410-49a6-9b4d-71b23afd15fa',
#  'data': {'order_id': '1326625682796821761'}}

# %%
await client.place_spot_limit_buy_order(
    product_symbol="BTC-USDT-SPOT",
    size="0.0001",
    price="80000",
    client_order_id="test",
)
# Out:
# {'message': 'OK',
#  'code': 1000,
#  'trace': '2cc4c54a-551d-4833-b88c-f3296a15b19a',
#  'data': {'order_id': '1326592454027361537'}}

# %%
await client.place_spot_post_only_limit_buy_order(
    product_symbol="BTC-USDT-SPOT",
    size="0.0001",
    price="80000",
    client_order_id="test",
)
# Out:
# {'message': 'OK',
#  'code': 1000,
#  'trace': '6e55f14d-0ec4-4b59-887c-e3a4c6b1bc6d',
#  'data': {'order_id': '1326592749725793537'}}

# %%
await client.cancel_spot_all_order()
# Out:
# {'message': 'OK',
#  'code': 1000,
#  'trace': 'baebf898-1b5f-4bc9-b8b1-50e2e76ddfe3',
#  'data': True}

# %%
await client.place_contract_market_buy_order(
    product_symbol="ETH-USDT-SWAP",
    size=1, # 0.001
)
# Out:
# {'code': 1000,
#  'message': 'Ok',
#  'data': {'order_id': 3000237066799793, 'price': 'market price'},
#  'trace': 'fc0d697c-516b-453e-b736-7795d8e7e5f9'}

# %%
await client.place_contract_market_sell_order(
    product_symbol="ETH-USDT-SWAP",
    size=1,
)
# Out:
# {'code': 1000,
#  'message': 'Ok',
#  'data': {'order_id': 3000237072797928, 'price': 'market price'},
#  'trace': 'b3a1889e-b72d-465c-9f25-29540814617e'}

# %%
await client.place_contract_post_only_buy_order(
    product_symbol="BTC-USDT-SWAP",
    price="84590",
    size=1,
)
# Out:
# {'code': 1000,
#  'message': 'Ok',
#  'data': {'order_id': 3000115472065417, 'price': '84590'},
#  'trace': '1e17720eff0f4ff9b15278e1f42685b4.98.17448964543265609'}

# %%
await client.place_contract_post_only_sell_order(
    product_symbol="BTC-USDT-SWAP",
    price="84595",
    size=1,
)
# Out:
# {'code': 1000,
#  'message': 'Ok',
#  'data': {'order_id': 3000115480064510, 'price': '84595'},
#  'trace': '1e17720eff0f4ff9b15278e1f42685b4.80.17448964778269058'}

# %%
await client.cancel_all_contract_order(product_symbol="BTC-USDT-SWAP")
# Out:
# {'code': 1000,
#  'message': 'Ok',
#  'data': {},
#  'trace': '1e17720eff0f4ff9b15278e1f42685b4.97.17449587454968093'}

# %%
await client.get_spot_order_by_order_id(orderId="1038391972626918401")
# Out:
# {'trace': '929cd5bc-8859-4eb9-b15f-c2f8b9720915',
#  'code': 1000,
#  'message': 'success',
#  'success': True,
#  'data': {'cancelSource': 'system',
#   'symbol': 'APT_USDT',
#   'price': '0.0000',
#   'state': 'partially_canceled',
#   'notional': '9.99000000',
#   'type': 'market',
#   'size': '0.0',
#   'filledNotional': '9.74425000',
#   'updateTime': 1744892984689,
#   'orderId': '1038391972626918401',
#   'createTime': 1744892984666,
#   'filledSize': '2.1',
#   'side': 'buy',
#   'orderMode': 'spot',
#   'priceAvg': '4.6401',
#   'clientOrderId': ''}}

# %%
await client.get_spot_open_orders()
# Out:
# {'data': [],
#  'success': True,
#  'code': 1000,
#  'trace': '838a9992-ad3b-49e4-8282-282d07009206',
#  'message': 'success'}

# %%
await client.get_spot_account_orders()
# Out:
# {'data': [{'orderId': '1326625682796821761',
#    'clientOrderId': '',
#    'priceAvg': '3.4000',
#    'filledSize': '2.2',
#    'price': '0.0000',
#    'side': 'sell',
#    'orderMode': 'spot',
#    'type': 'market',
#    'cancelSource': '',
#    'stpMode': 'none',
#    'updateTime': 1762073052592,
#    'state': 'filled',
#    'notional': '0.00000000',
#    'symbol': 'APT_USDT',
#    'createTime': 1762073052573,
#    'filledNotional': '7.48000000',
#    'size': '2.2'},
#   {'orderId': '1326625441708227840',
#    'clientOrderId': '',
#    'priceAvg': '3.4030',
#    'filledSize': '1.4',
#    'price': '0.0000',
#    'side': 'buy',
#    'orderMode': 'spot',
#    'type': 'market',
#    'cancelSource': 'system',
#    'stpMode': 'none',
#    'updateTime': 1762073038222,
#    'state': 'partially_canceled',
#    'notional': '4.99500000',
#    'symbol': 'APT_USDT',
#    'createTime': 1762073038203,
#    'filledNotional': '4.76420000',
#    'size': '0.0'},
#   {'orderId': '1326591908381965568',
#    'clientOrderId': '',
#    'priceAvg': '3.3820',
#    'filledSize': '2.1',
#    'price': '0.0000',
#    'side': 'sell',
#    'orderMode': 'spot',
#    'type': 'market',
#    'cancelSource': '',
#    'stpMode': 'none',
#    'updateTime': 1762071039483,
#    'state': 'filled',
#    'notional': '0.00000000',
#    'symbol': 'APT_USDT',
#    'createTime': 1762071039461,
#    'filledNotional': '7.10220000',
#    'size': '2.1'},
#   {'orderId': '1326591866891910401',
#    'clientOrderId': '',
#    'priceAvg': '3.3850',
#    'filledSize': '2.9',
#    'price': '0.0000',
#    'side': 'buy',
#    'orderMode': 'spot',
#    'type': 'market',
#    'cancelSource': 'system',
#    'stpMode': 'none',
#    'updateTime': 1762071037011,
#    'state': 'partially_canceled',
#    'notional': '9.99000000',
#    'symbol': 'APT_USDT',
#    'createTime': 1762071036988,
#    'filledNotional': '9.81650000',
#    'size': '0.0'}],
#  'success': True,
#  'code': 1000,
#  'trace': '065764b3-e18b-4620-a0c7-9f59cf84a2f5',
#  'message': 'success'}

# %%
await client.get_spot_account_trade_list()
# Out:
# {'trace': '40794aaf-6295-4c40-b1c1-0b6857293c16',
#  'code': 1000,
#  'message': 'success',
#  'success': True,
#  'data': [{'clientOrderId': '',
#    'side': 'buy',
#    'orderMode': 'spot',
#    'price': '2.24987',
#    'type': 'market',
#    'size': '8.7',
#    'updateTime': 1745242050313,
#    'fee': '0.01957387',
#    'tradeId': '1044248322351421958',
#    'feeCoinName': 'USDT',
#    'notional': '19.57386900',
#    'tradeRole': 'taker',
#    'symbol': 'SUI_USDT',
#    'orderId': '1044248322317708288',
#    'createTime': 1745242050313},
#   {'clientOrderId': '',
#    'side': 'buy',
#    'orderMode': 'spot',
#    'price': '2.24961',
#    'type': 'market',
#    'size': '2.2',
#    'updateTime': 1745241940219,
#    'fee': '0.00494914',
#    'tradeId': '1044246475280603660',
#    'feeCoinName': 'USDT',
#    'notional': '4.94914200',
#    'tradeRole': 'taker',
#    'symbol': 'SUI_USDT',
#    'orderId': '1044246475213335552',
#    'createTime': 1745241940219},
#   {'clientOrderId': '',
#    'side': 'sell',
#    'orderMode': 'spot',
#    'price': '4.5873',
#    'type': 'market',
#    'size': '2.1',
#    'updateTime': 1744958998071,
#    'fee': '0.00963333',
#    'tradeId': '1039499493747208454',
#    'feeCoinName': 'USDT',
#    'notional': '9.63333000',
#    'tradeRole': 'taker',
#    'symbol': 'APT_USDT',
#    'orderId': '1039499493714390017',
#    'createTime': 1744958998071},
#   {'clientOrderId': '',
#    'side': 'buy',
#    'orderMode': 'spot',
#    'price': '4.6236',
#    'type': 'market',
#    'size': '1.0',
#    'updateTime': 1744958768719,
#    'fee': '0.00462360',
#    'tradeId': '1039495645842387204',
#    'feeCoinName': 'USDT',
#    'notional': '4.62360000',
#    'tradeRole': 'taker',
#    'symbol': 'APT_USDT',
#    'orderId': '1039495645524356096',
#    'createTime': 1744958768719},
#   {'clientOrderId': '',
#    'side': 'buy',
#    'orderMode': 'spot',
#    'price': '4.6235',
#    'type': 'market',
#    'size': '1.1',
#    'updateTime': 1744958768718,
#    'fee': '0.00508585',
#    'tradeId': '1039495645842387201',
#    'feeCoinName': 'USDT',
#    'notional': '5.08585000',
#    'tradeRole': 'taker',
#    'symbol': 'APT_USDT',
#    'orderId': '1039495645524356096',
#    'createTime': 1744958768718},
#   {'clientOrderId': '',
#    'side': 'sell',
#    'orderMode': 'spot',
#    'price': '4.6109',
#    'type': 'market',
#    'size': '2.1',
#    'updateTime': 1744892986828,
#    'fee': '0.00968289',
#    'tradeId': '1038392008864968968',
#    'feeCoinName': 'USDT',
#    'notional': '9.68289000',
#    'tradeRole': 'taker',
#    'symbol': 'APT_USDT',
#    'orderId': '1038392008647601152',
#    'createTime': 1744892986828},
#   {'clientOrderId': '',
#    'side': 'buy',
#    'orderMode': 'spot',
#    'price': '4.6402',
#    'type': 'market',
#    'size': '0.4',
#    'updateTime': 1744892984688,
#    'fee': '0.00185608',
#    'tradeId': '1038391972944949518',
#    'feeCoinName': 'USDT',
#    'notional': '1.85608000',
#    'tradeRole': 'taker',
#    'symbol': 'APT_USDT',
#    'orderId': '1038391972626918401',
#    'createTime': 1744892984688},
#   {'clientOrderId': '',
#    'side': 'buy',
#    'orderMode': 'spot',
#    'price': '4.6401',
#    'type': 'market',
#    'size': '1.7',
#    'updateTime': 1744892984687,
#    'fee': '0.00788817',
#    'tradeId': '1038391972944949515',
#    'feeCoinName': 'USDT',
#    'notional': '7.88817000',
#    'tradeRole': 'taker',
#    'symbol': 'APT_USDT',
#    'orderId': '1038391972626918401',
#    'createTime': 1744892984687},
#   {'clientOrderId': '',
#    'side': 'sell',
#    'orderMode': 'spot',
#    'price': '4.6060',
#    'type': 'market',
#    'size': '2.1',
#    'updateTime': 1744892665972,
#    'fee': '0.00967260',
#    'tradeId': '1038386625794552065',
#    'feeCoinName': 'USDT',
#    'notional': '9.67260000',
#    'tradeRole': 'taker',
#    'symbol': 'APT_USDT',
#    'orderId': '1038386625442966529',
#    'createTime': 1744892665972},
#   {'clientOrderId': '',
#    'side': 'buy',
#    'orderMode': 'spot',
#    'price': '4.6298',
#    'type': 'market',
#    'size': '2.1',
#    'updateTime': 1744892487734,
#    'fee': '0.00972258',
#    'tradeId': '1038383635457126658',
#    'feeCoinName': 'USDT',
#    'notional': '9.72258000',
#    'tradeRole': 'taker',
#    'symbol': 'APT_USDT',
#    'orderId': '1038383635139095552',
#    'createTime': 1744892487734}]}

# %%
await client.get_spot_order_trade_list(orderId="1038391972626918401")
# Out:
# {'message': 'success',
#  'code': 1000,
#  'data': [{'side': 'buy',
#    'notional': '1.85608000',
#    'price': '4.6402',
#    'tradeRole': 'taker',
#    'createTime': 1744892984688,
#    'orderId': '1038391972626918401',
#    'updateTime': 1744892984688,
#    'clientOrderId': '',
#    'tradeId': '1038391972944949518',
#    'orderMode': 'spot',
#    'fee': '0.00185608',
#    'type': 'market',
#    'size': '0.4',
#    'feeCoinName': 'USDT',
#    'symbol': 'APT_USDT'},
#   {'side': 'buy',
#    'notional': '7.88817000',
#    'price': '4.6401',
#    'tradeRole': 'taker',
#    'createTime': 1744892984687,
#    'orderId': '1038391972626918401',
#    'updateTime': 1744892984687,
#    'clientOrderId': '',
#    'tradeId': '1038391972944949515',
#    'orderMode': 'spot',
#    'fee': '0.00788817',
#    'type': 'market',
#    'size': '1.7',
#    'feeCoinName': 'USDT',
#    'symbol': 'APT_USDT'}],
#  'success': True,
#  'trace': '250d48f3-1501-49b0-b327-550e49e479b2'}

# %%
await client.get_contract_order_history(product_symbol="ETH-USDT-SWAP")
# Out:
# {'code': 1000,
#  'message': 'Ok',
#  'data': [{'order_id': '3000115480062033',
#    'client_order_id': '',
#    'price': '0',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'market',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '1594.15',
#    'deal_size': '1',
#    'create_time': 1744896025308,
#    'update_time': 1744896025427,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000115480062032',
#    'client_order_id': '',
#    'price': '0',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 3,
#    'type': 'market',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '1594.03',
#    'deal_size': '1',
#    'create_time': 1744896025287,
#    'update_time': 1744896025409,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000115472045185',
#    'client_order_id': '',
#    'price': '1604.7',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'market',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '1599.9',
#    'deal_size': '1',
#    'create_time': 1744892990773,
#    'update_time': 1744892990873,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000115472045174',
#    'client_order_id': '',
#    'price': '0',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'market',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '1600.02',
#    'deal_size': '1',
#    'create_time': 1744892988603,
#    'update_time': 1744892988723,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000115472045106',
#    'client_order_id': '',
#    'price': '1604.62',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'market',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '1599.82',
#    'deal_size': '1',
#    'create_time': 1744892970490,
#    'update_time': 1744892970529,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000115480044163',
#    'client_order_id': '',
#    'price': '1604.68',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'market',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '1599.84',
#    'deal_size': '1',
#    'create_time': 1744892962937,
#    'update_time': 1744892963029,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631237',
#    'client_order_id': '',
#    'price': '0',
#    'size': '6',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'market',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '1810.75',
#    'deal_size': '6',
#    'create_time': 1743905584400,
#    'update_time': 1743905584497,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627554',
#    'client_order_id': '',
#    'price': '1811.29',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905576101,
#    'update_time': 1743905576194,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631135',
#    'client_order_id': '',
#    'price': '1810.2',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905575950,
#    'update_time': 1743905575984,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627547',
#    'client_order_id': '',
#    'price': '1811.11',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905575642,
#    'update_time': 1743905587365,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631126',
#    'client_order_id': '',
#    'price': '1810.38',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905575444,
#    'update_time': 1743905584382,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627542',
#    'client_order_id': '',
#    'price': '1810.93',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905575246,
#    'update_time': 1743905587354,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631121',
#    'client_order_id': '',
#    'price': '1810.56',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905575051,
#    'update_time': 1743905584372,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631101',
#    'client_order_id': '',
#    'price': '1811.27',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905573328,
#    'update_time': 1743905573379,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627520',
#    'client_order_id': '',
#    'price': '1810.19',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905573185,
#    'update_time': 1743905573270,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631097',
#    'client_order_id': '',
#    'price': '1811.09',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905572891,
#    'update_time': 1743905574910,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627514',
#    'client_order_id': '',
#    'price': '1810.37',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905572700,
#    'update_time': 1743905574934,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627512',
#    'client_order_id': '',
#    'price': '1810.91',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905572497,
#    'update_time': 1743905574922,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631091',
#    'client_order_id': '',
#    'price': '1810.55',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905572220,
#    'update_time': 1743905574899,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631043',
#    'client_order_id': '',
#    'price': '1811.28',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905567599,
#    'update_time': 1743905567672,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631040',
#    'client_order_id': '',
#    'price': '1810.2',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905567419,
#    'update_time': 1743905567461,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631036',
#    'client_order_id': '',
#    'price': '1811.1',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905567124,
#    'update_time': 1743905569211,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631034',
#    'client_order_id': '',
#    'price': '1810.38',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905566912,
#    'update_time': 1743905569199,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631030',
#    'client_order_id': '',
#    'price': '1810.92',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905566706,
#    'update_time': 1743905569187,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627442',
#    'client_order_id': '',
#    'price': '1810.56',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905566486,
#    'update_time': 1743905569224,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631009',
#    'client_order_id': '',
#    'price': '1811.29',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905564756,
#    'update_time': 1743905564873,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627419',
#    'client_order_id': '',
#    'price': '1810.2',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905564612,
#    'update_time': 1743905564661,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388631007',
#    'client_order_id': '',
#    'price': '1811.11',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905564309,
#    'update_time': 1743905566407,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627415',
#    'client_order_id': '',
#    'price': '1810.38',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905564116,
#    'update_time': 1743905566444,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627412',
#    'client_order_id': '',
#    'price': '1810.93',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905563909,
#    'update_time': 1743905566433,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627410',
#    'client_order_id': '',
#    'price': '1810.56',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905563711,
#    'update_time': 1743905566421,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630985',
#    'client_order_id': '',
#    'price': '1811.28',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905561893,
#    'update_time': 1743905563647,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627388',
#    'client_order_id': '',
#    'price': '1810.2',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905561690,
#    'update_time': 1743905561788,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630977',
#    'client_order_id': '',
#    'price': '1811.1',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905561393,
#    'update_time': 1743905563638,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630976',
#    'client_order_id': '',
#    'price': '1810.38',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905561187,
#    'update_time': 1743905563628,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630968',
#    'client_order_id': '',
#    'price': '1810.92',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905560983,
#    'update_time': 1743905563618,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630963',
#    'client_order_id': '',
#    'price': '1810.56',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905560779,
#    'update_time': 1743905563607,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630929',
#    'client_order_id': '',
#    'price': '1811.21',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905557573,
#    'update_time': 1743905557699,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627349',
#    'client_order_id': '',
#    'price': '1810.13',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905557423,
#    'update_time': 1743905557486,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630926',
#    'client_order_id': '',
#    'price': '1811.03',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905557116,
#    'update_time': 1743905559248,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630925',
#    'client_order_id': '',
#    'price': '1810.31',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905556910,
#    'update_time': 1743905559238,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630920',
#    'client_order_id': '',
#    'price': '1810.85',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905556712,
#    'update_time': 1743905559226,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630916',
#    'client_order_id': '',
#    'price': '1810.49',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905556516,
#    'update_time': 1743905559217,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627320',
#    'client_order_id': '',
#    'price': '1811.22',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905554790,
#    'update_time': 1743905554898,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627317',
#    'client_order_id': '',
#    'price': '1810.13',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905554640,
#    'update_time': 1743905554685,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627313',
#    'client_order_id': '',
#    'price': '1811.04',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905554344,
#    'update_time': 1743905556470,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630885',
#    'client_order_id': '',
#    'price': '1810.31',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905554140,
#    'update_time': 1743905556436,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627308',
#    'client_order_id': '',
#    'price': '1810.86',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905553925,
#    'update_time': 1743905556459,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627306',
#    'client_order_id': '',
#    'price': '1810.49',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905553722,
#    'update_time': 1743905556449,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627296',
#    'client_order_id': '',
#    'price': '1811.35',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905551998,
#    'update_time': 1743905552119,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627295',
#    'client_order_id': '',
#    'price': '1810.26',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905551831,
#    'update_time': 1743905551896,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627293',
#    'client_order_id': '',
#    'price': '1811.17',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905551525,
#    'update_time': 1743905553666,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630856',
#    'client_order_id': '',
#    'price': '1810.44',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905551311,
#    'update_time': 1743905553646,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627285',
#    'client_order_id': '',
#    'price': '1810.99',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905551102,
#    'update_time': 1743905553657,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630846',
#    'client_order_id': '',
#    'price': '1810.62',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905550893,
#    'update_time': 1743905553636,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627252',
#    'client_order_id': '',
#    'price': '1811.37',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905549156,
#    'update_time': 1743905549275,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630810',
#    'client_order_id': '',
#    'price': '1810.29',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905549010,
#    'update_time': 1743905549064,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630808',
#    'client_order_id': '',
#    'price': '1811.19',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905548697,
#    'update_time': 1743905550763,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627247',
#    'client_order_id': '',
#    'price': '1810.47',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905548502,
#    'update_time': 1743905550778,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630804',
#    'client_order_id': '',
#    'price': '1811.01',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905548310,
#    'update_time': 1743905550748,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630802',
#    'client_order_id': '',
#    'price': '1810.65',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905548105,
#    'update_time': 1743905550731,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630780',
#    'client_order_id': '',
#    'price': '1811.52',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905546349,
#    'update_time': 1743905546389,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627209',
#    'client_order_id': '',
#    'price': '1810.43',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905546204,
#    'update_time': 1743905546277,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627207',
#    'client_order_id': '',
#    'price': '1811.34',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905545908,
#    'update_time': 1743905548048,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627205',
#    'client_order_id': '',
#    'price': '1810.61',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905545713,
#    'update_time': 1743905548034,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627200',
#    'client_order_id': '',
#    'price': '1811.16',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905545520,
#    'update_time': 1743905548019,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630771',
#    'client_order_id': '',
#    'price': '1810.79',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905545320,
#    'update_time': 1743905548008,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627177',
#    'client_order_id': '',
#    'price': '1811.42',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905543562,
#    'update_time': 1743905543593,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627174',
#    'client_order_id': '',
#    'price': '1810.34',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905543413,
#    'update_time': 1743905543482,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627171',
#    'client_order_id': '',
#    'price': '1811.24',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905543106,
#    'update_time': 1743905545263,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627169',
#    'client_order_id': '',
#    'price': '1810.52',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905542911,
#    'update_time': 1743905545252,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627166',
#    'client_order_id': '',
#    'price': '1811.06',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905542722,
#    'update_time': 1743905545242,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630731',
#    'client_order_id': '',
#    'price': '1810.7',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905542504,
#    'update_time': 1743905545231,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627149',
#    'client_order_id': '',
#    'price': '1811.43',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905540751,
#    'update_time': 1743905542369,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627146',
#    'client_order_id': '',
#    'price': '1810.35',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905540545,
#    'update_time': 1743905540615,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627140',
#    'client_order_id': '',
#    'price': '1811.25',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905539922,
#    'update_time': 1743905542360,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630708',
#    'client_order_id': '',
#    'price': '1810.53',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905539716,
#    'update_time': 1743905542331,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627131',
#    'client_order_id': '',
#    'price': '1811.07',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905539509,
#    'update_time': 1743905542351,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627130',
#    'client_order_id': '',
#    'price': '1810.71',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905539302,
#    'update_time': 1743905542341,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627100',
#    'client_order_id': '',
#    'price': '1811.44',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905535982,
#    'update_time': 1743905536020,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630666',
#    'client_order_id': '',
#    'price': '1810.36',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905535839,
#    'update_time': 1743905535908,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630663',
#    'client_order_id': '',
#    'price': '1811.26',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905535556,
#    'update_time': 1743905537652,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630662',
#    'client_order_id': '',
#    'price': '1810.54',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905535367,
#    'update_time': 1743905537641,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627090',
#    'client_order_id': '',
#    'price': '1811.08',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905535156,
#    'update_time': 1743905537673,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627086',
#    'client_order_id': '',
#    'price': '1810.72',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905534950,
#    'update_time': 1743905537663,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630595',
#    'client_order_id': '',
#    'price': '1811.48',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905530293,
#    'update_time': 1743905530399,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627031',
#    'client_order_id': '',
#    'price': '1810.39',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905530139,
#    'update_time': 1743905530187,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630590',
#    'client_order_id': '',
#    'price': '1811.3',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905529845,
#    'update_time': 1743905531928,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627025',
#    'client_order_id': '',
#    'price': '1810.57',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905529645,
#    'update_time': 1743905531949,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630586',
#    'client_order_id': '',
#    'price': '1811.12',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905529449,
#    'update_time': 1743905531916,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391627019',
#    'client_order_id': '',
#    'price': '1810.75',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905529252,
#    'update_time': 1743905531939,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630565',
#    'client_order_id': '',
#    'price': '1811.47',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905527516,
#    'update_time': 1743905527600,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630563',
#    'client_order_id': '',
#    'price': '1810.39',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905527357,
#    'update_time': 1743905527387,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630560',
#    'client_order_id': '',
#    'price': '1811.29',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905527044,
#    'update_time': 1743905529173,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630557',
#    'client_order_id': '',
#    'price': '1810.57',
#    'size': '1',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905526838,
#    'update_time': 1743905529162,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630554',
#    'client_order_id': '',
#    'price': '1811.11',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905526637,
#    'update_time': 1743905529151,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630552',
#    'client_order_id': '',
#    'price': '1810.75',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 2,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905526430,
#    'update_time': 1743905529140,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630523',
#    'client_order_id': '',
#    'price': '1811.48',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905524680,
#    'update_time': 1743905524802,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107388630521',
#    'client_order_id': '',
#    'price': '1810.39',
#    'size': '5',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 1,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905524531,
#    'update_time': 1743905524589,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'},
#   {'order_id': '3000107391626937',
#    'client_order_id': '',
#    'price': '1811.3',
#    'size': '2',
#    'symbol': 'ETHUSDT',
#    'state': 4,
#    'side': 4,
#    'type': 'limit',
#    'leverage': '50',
#    'open_type': 'cross',
#    'deal_avg_price': '0',
#    'deal_size': '0',
#    'create_time': 1743905524231,
#    'update_time': 1743905526358,
#    'activation_price_type': 1,
#    'activation_price': '0',
#    'callback_rate': '0',
#    'preset_take_profit_price_type': 0,
#    'preset_stop_loss_price_type': 0,
#    'preset_take_profit_price': '',
#    'preset_stop_loss_price': '',
#    'account': 'futures',
#    'position_mode': 'hedge_mode'}],
#  'trace': '1e17720eff0f4ff9b15278e1f42685b4.95.17453899425610102'}

# %%
await client.get_contract_open_order(product_symbol="ETH-USDT-SWAP")
# Out:
# {'code': 1000,
#  'message': 'Ok',
#  'data': [],
#  'trace': 'b15f261868b540889e57f826e0420621.98.17453899455926276'}

# %%
await client.get_contract_position(product_symbol="ETH-USDT-SWAP")
# Out:
# {'code': 1000,
#  'message': 'Ok',
#  'data': [],
#  'trace': 'b15f261868b540889e57f826e0420621.88.17453899469028801'}

# %%
await client.get_contract_trade(product_symbol="ETH-USDT-SWAP")
# Out:
# {'code': 1000,
#  'message': 'Ok',
#  'data': [{'order_id': '3000115480062033',
#    'trade_id': '3000000323007999',
#    'symbol': 'ETHUSDT',
#    'side': 2,
#    'price': '1594.15',
#    'vol': '1',
#    'exec_type': 'Taker',
#    'profit': True,
#    'create_time': 1744896025319,
#    'realised_profit': '0.00575',
#    'paid_fees': '0.0003985375',
#    'account': 'futures'},
#   {'order_id': '3000115480062032',
#    'trade_id': '3000000323007998',
#    'symbol': 'ETHUSDT',
#    'side': 3,
#    'price': '1594.03',
#    'vol': '1',
#    'exec_type': 'Taker',
#    'profit': False,
#    'create_time': 1744896025297,
#    'realised_profit': '-0.00581',
#    'paid_fees': '0.0003985075',
#    'account': 'futures'},
#   {'order_id': '3000115472045185',
#    'trade_id': '3000000322954274',
#    'symbol': 'ETHUSDT',
#    'side': 4,
#    'price': '1599.9',
#    'vol': '1',
#    'exec_type': 'Taker',
#    'profit': False,
#    'create_time': 1744892990788,
#    'realised_profit': '0',
#    'paid_fees': '0.000399975',
#    'account': 'futures'},
#   {'order_id': '3000115472045174',
#    'trade_id': '3000000322954241',
#    'symbol': 'ETHUSDT',
#    'side': 2,
#    'price': '1600.02',
#    'vol': '1',
#    'exec_type': 'Taker',
#    'profit': False,
#    'create_time': 1744892988616,
#    'realised_profit': '-0.0002',
#    'paid_fees': '0.000400005',
#    'account': 'futures'},
#   {'order_id': '3000115472045106',
#    'trade_id': '3000000322953962',
#    'symbol': 'ETHUSDT',
#    'side': 4,
#    'price': '1599.82',
#    'vol': '1',
#    'exec_type': 'Taker',
#    'profit': False,
#    'create_time': 1744892970498,
#    'realised_profit': '0',
#    'paid_fees': '0.000399955',
#    'account': 'futures'},
#   {'order_id': '3000115480044163',
#    'trade_id': '3000000322953845',
#    'symbol': 'ETHUSDT',
#    'side': 1,
#    'price': '1599.84',
#    'vol': '1',
#    'exec_type': 'Taker',
#    'profit': False,
#    'create_time': 1744892962946,
#    'realised_profit': '0',
#    'paid_fees': '0.00039996',
#    'account': 'futures'}],
#  'trace': 'b15f261868b540889e57f826e0420621.68.17453899484735832'}

# %%
await client.get_contract_transaction_history(product_symbol="ETH-USDT-SWAP")
# Out:
# {'code': 1000,
#  'message': 'Ok',
#  'data': [{'time': '1745242044231',
#    'type': 'Transfer',
#    'amount': '-10',
#    'asset': 'USDT',
#    'symbol': '',
#    'tran_id': '955261',
#    'flow_type': 1,
#    'account': 'futures'},
#   {'time': '1744896025319',
#    'type': 'Realized PNL',
#    'amount': '0.00575',
#    'asset': 'USDT',
#    'symbol': 'ETHUSDT',
#    'tran_id': '1039532',
#    'flow_type': 2,
#    'account': 'futures'},
#   {'time': '1744896025319',
#    'type': 'Commission Fee',
#    'amount': '-0.00039853',
#    'asset': 'USDT',
#    'symbol': 'ETHUSDT',
#    'tran_id': '1039532',
#    'flow_type': 4,
#    'account': 'futures'},
#   {'time': '1744896025297',
#    'type': 'Realized PNL',
#    'amount': '-0.00581',
#    'asset': 'USDT',
#    'symbol': 'ETHUSDT',
#    'tran_id': '1039531',
#    'flow_type': 2,
#    'account': 'futures'},
#   {'time': '1744896025297',
#    'type': 'Commission Fee',
#    'amount': '-0.0003985',
#    'asset': 'USDT',
#    'symbol': 'ETHUSDT',
#    'tran_id': '1039531',
#    'flow_type': 4,
#    'account': 'futures'},
#   {'time': '1744892990788',
#    'type': 'Commission Fee',
#    'amount': '-0.00039997',
#    'asset': 'USDT',
#    'symbol': 'ETHUSDT',
#    'tran_id': '1039460',
#    'flow_type': 4,
#    'account': 'futures'},
#   {'time': '1744892988616',
#    'type': 'Realized PNL',
#    'amount': '-0.0002',
#    'asset': 'USDT',
#    'symbol': 'ETHUSDT',
#    'tran_id': '1039459',
#    'flow_type': 2,
#    'account': 'futures'},
#   {'time': '1744892988616',
#    'type': 'Commission Fee',
#    'amount': '-0.0004',
#    'asset': 'USDT',
#    'symbol': 'ETHUSDT',
#    'tran_id': '1039459',
#    'flow_type': 4,
#    'account': 'futures'},
#   {'time': '1744892970498',
#    'type': 'Commission Fee',
#    'amount': '-0.00039995',
#    'asset': 'USDT',
#    'symbol': 'ETHUSDT',
#    'tran_id': '1039458',
#    'flow_type': 4,
#    'account': 'futures'},
#   {'time': '1744892962946',
#    'type': 'Commission Fee',
#    'amount': '-0.00039996',
#    'asset': 'USDT',
#    'symbol': 'ETHUSDT',
#    'tran_id': '1039457',
#    'flow_type': 4,
#    'account': 'futures'},
#   {'time': '1744823922895',
#    'type': 'Transfer',
#    'amount': '10',
#    'asset': 'USDT',
#    'symbol': '',
#    'tran_id': '948029',
#    'flow_type': 1,
#    'account': 'futures'}],
#  'trace': 'b15f261868b540889e57f826e0420621.96.17453899503286318'}

# %%
await client.get_contract_transfer_list(page=1, limit=10)
# Out:
# {'message': 'OK',
#  'code': 1000,
#  'trace': '1e17720eff0f4ff9b15278e1f42685b4.63.17453899534403638',
#  'data': {'records': [{'transfer_id': '1111807559313616896',
#     'currency': 'USDT',
#     'amount': '10',
#     'type': 'contract_to_spot',
#     'state': 'FINISHED',
#     'timestamp': 1745242044156},
#    {'transfer_id': '1110053831120220160',
#     'currency': 'USDT',
#     'amount': '10',
#     'type': 'spot_to_contract',
#     'state': 'FINISHED',
#     'timestamp': 1744823922772},
#    {'transfer_id': '1106420578823925760',
#     'currency': 'USDT',
#     'amount': '55.64',
#     'type': 'contract_to_spot',
#     'state': 'FINISHED',
#     'timestamp': 1743957687922},
#    {'transfer_id': '1102755032903413760',
#     'currency': 'USDT',
#     'amount': '36.37',
#     'type': 'spot_to_contract',
#     'state': 'FINISHED',
#     'timestamp': 1743083753672},
#    {'transfer_id': '1102431185264144384',
#     'currency': 'USDT',
#     'amount': '40',
#     'type': 'spot_to_contract',
#     'state': 'FINISHED',
#     'timestamp': 1743006542378},
#    {'transfer_id': '1102427213405057024',
#     'currency': 'USDT',
#     'amount': '31.8',
#     'type': 'contract_to_spot',
#     'state': 'FINISHED',
#     'timestamp': 1743005595413},
#    {'transfer_id': '1100497346342121472',
#     'currency': 'USDT',
#     'amount': '41.38',
#     'type': 'spot_to_contract',
#     'state': 'FINISHED',
#     'timestamp': 1742545479250},
#    {'transfer_id': '1095295712402042880',
#     'currency': 'USDT',
#     'amount': '27.48',
#     'type': 'contract_to_spot',
#     'state': 'FINISHED',
#     'timestamp': 1741305313077},
#    {'transfer_id': '1095295574476550144',
#     'currency': 'USDT',
#     'amount': '7.31',
#     'type': 'spot_to_contract',
#     'state': 'FINISHED',
#     'timestamp': 1741305280193},
#    {'transfer_id': '1091900523218169856',
#     'currency': 'USDT',
#     'amount': '2.11',
#     'type': 'contract_to_spot',
#     'state': 'FINISHED',
#     'timestamp': 1740495836896}]}}

# %%
await client.get_contract_order_detail(product_symbol="BTC-USDT-SWAP", order_id="3000115472065417")
